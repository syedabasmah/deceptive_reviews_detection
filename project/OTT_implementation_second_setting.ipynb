# %% [markdown]
# <a href="https://colab.research.google.com/github/syedabasmah/deceptive_reviews_detection/blob/main/project/OTT_implementation_second_setting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Ott Dataset Implementation**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **First Phase: PRE-PROCESSING**

# %% [markdown]
# This includes data analysis, train-test split & building NLP pipeline

# %% [markdown]
# **Import the libraries:**

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Read the file:**

# %%
df = pd.read_csv('/content/drive/MyDrive/deceptive-opinion.csv')

# %% [markdown]
# **Data analysis:**

# %%
df.describe()
# Out:
#        deceptive   hotel  polarity source  \
# count       1600    1600      1600   1600
# unique         2      20         2      3
# top     truthful  conrad  positive  MTurk
# freq         800      80       800    800
#
#                                                      text
# count                                                1600
# unique                                               1596
# top     The Omni was chosen for it's location whichwor...
# freq                                                    2

# %%
df.deceptive.value_counts()
# Out:
# truthful     800
# deceptive    800
# Name: deceptive, dtype: int64

# %%
df.head()
# Out:
#   deceptive   hotel  polarity       source  \
# 0  truthful  conrad  positive  TripAdvisor
# 1  truthful   hyatt  positive  TripAdvisor
# 2  truthful   hyatt  positive  TripAdvisor
# 3  truthful    omni  positive  TripAdvisor
# 4  truthful   hyatt  positive  TripAdvisor
#
#                                                 text
# 0  We stayed for a one night getaway with family ...
# 1  Triple A rate with upgrade to view room was le...
# 2  This comes a little late as I'm finally catchi...
# 3  The Omni Chicago really delivers on all fronts...
# 4  I asked for a high floor away from the elevato...

# %%
df.shape
# Out:
# (1600, 5)

# %% [markdown]
# **Are there any missing values?**

# %%
df.isnull().sum()
# Out:
# deceptive    0
# hotel        0
# polarity     0
# source       0
# text         0
# dtype: int64

# %%
df.dtypes
# Out:
# deceptive    object
# hotel        object
# polarity     object
# source       object
# text         object
# dtype: object

# %% [markdown]
# **Drop irrelevant features (i.e., hotel, source, polarity):**

# %%
df.drop(['hotel', 'source', 'polarity'], axis=1, inplace=True)

# %%
df.shape
# Out:
# (1600, 2)

# %% [markdown]
# **Applying label encoding to the target feature (i.e., deceptive):**

# %%
from sklearn.preprocessing import LabelEncoder
df['deceptive_LabEnc'] = LabelEncoder().fit_transform(df['deceptive'])
df.drop('deceptive', axis=1, inplace=True)

# %%
df.head()
# Out:
#                                                 text  deceptive_LabEnc
# 0  We stayed for a one night getaway with family ...                 1
# 1  Triple A rate with upgrade to view room was le...                 1
# 2  This comes a little late as I'm finally catchi...                 1
# 3  The Omni Chicago really delivers on all fronts...                 1
# 4  I asked for a high floor away from the elevato...                 1

# %% [markdown]
# **Building Natural Language Processing (NLP) pipeline:**

# %% [markdown]
# **1. Removing punctuation:**

# %%
import string
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
def remove_punctuation(txt):
  txt_nopunc = "".join([c for c in txt if c not in string.punctuation])
  return txt_nopunc

# %%
df['text_no_punc'] = df['text'].apply(lambda x: remove_punctuation(x))

# %%
df.head()
# Out:
#                                                 text  deceptive_LabEnc  \
# 0  We stayed for a one night getaway with family ...                 1
# 1  Triple A rate with upgrade to view room was le...                 1
# 2  This comes a little late as I'm finally catchi...                 1
# 3  The Omni Chicago really delivers on all fronts...                 1
# 4  I asked for a high floor away from the elevato...                 1
#
#                                         text_no_punc
# 0  We stayed for a one night getaway with family ...
# 1  Triple A rate with upgrade to view room was le...
# 2  This comes a little late as Im finally catchin...
# 3  The Omni Chicago really delivers on all fronts...
# 4  I asked for a high floor away from the elevato...

# %% [markdown]
# **2. Tokenization:**

# %%
import re #regular expression (built in package)

def tokenize(txt):
  tokens = re.split('\W+', txt)
  return tokens 

df['text_tokenized'] = df['text_no_punc'].apply(lambda x: tokenize(x.lower()))

# %%
df.head()
# Out:
#                                                 text  deceptive_LabEnc  \
# 0  We stayed for a one night getaway with family ...                 1
# 1  Triple A rate with upgrade to view room was le...                 1
# 2  This comes a little late as I'm finally catchi...                 1
# 3  The Omni Chicago really delivers on all fronts...                 1
# 4  I asked for a high floor away from the elevato...                 1
#
#                                         text_no_punc  \
# 0  We stayed for a one night getaway with family ...
# 1  Triple A rate with upgrade to view room was le...
# 2  This comes a little late as Im finally catchin...
# 3  The Omni Chicago really delivers on all fronts...
# 4  I asked for a high floor away from the elevato...
#
#                                       text_tokenized
# 0  [we, stayed, for, a, one, night, getaway, with...
# 1  [triple, a, rate, with, upgrade, to, view, roo...
# 2  [this, comes, a, little, late, as, im, finally...
# 3  [the, omni, chicago, really, delivers, on, all...
# 4  [i, asked, for, a, high, floor, away, from, th...

# %% [markdown]
# **3. Removing stop words:**

# %%
import nltk
nltk.download('stopwords')
stopwords = nltk.corpus.stopwords.words('english')
stopwords[0:10]
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're"]

# %%
def remove_stopwords(text_tokenized):
  text_removed_stopwords = [word for word in text_tokenized if word not in stopwords]
  return text_removed_stopwords

df['text_no_stopword'] = df['text_tokenized'].apply(lambda x: remove_stopwords(x))

# %%
df.head()
# Out:
#                                                 text  deceptive_LabEnc  \
# 0  We stayed for a one night getaway with family ...                 1
# 1  Triple A rate with upgrade to view room was le...                 1
# 2  This comes a little late as I'm finally catchi...                 1
# 3  The Omni Chicago really delivers on all fronts...                 1
# 4  I asked for a high floor away from the elevato...                 1
#
#                                         text_no_punc  \
# 0  We stayed for a one night getaway with family ...
# 1  Triple A rate with upgrade to view room was le...
# 2  This comes a little late as Im finally catchin...
# 3  The Omni Chicago really delivers on all fronts...
# 4  I asked for a high floor away from the elevato...
#
#                                       text_tokenized  \
# 0  [we, stayed, for, a, one, night, getaway, with...
# 1  [triple, a, rate, with, upgrade, to, view, roo...
# 2  [this, comes, a, little, late, as, im, finally...
# 3  [the, omni, chicago, really, delivers, on, all...
# 4  [i, asked, for, a, high, floor, away, from, th...
#
#                                     text_no_stopword
# 0  [stayed, one, night, getaway, family, thursday...
# 1  [triple, rate, upgrade, view, room, less, 200,...
# 2  [comes, little, late, im, finally, catching, r...
# 3  [omni, chicago, really, delivers, fronts, spac...
# 4  [asked, high, floor, away, elevator, got, room...

# %% [markdown]
# **4. Stemming**

# %% [markdown]
# You may perform any of the two i.e., stemming or lemmatization
# A better efficient way to proceed is to first lemmatise and then stem, but stemming alone is also fine for few problems statements, here we will not lemmatise.

# %%
import nltk
from nltk.stem import PorterStemmer
ps = PorterStemmer()
dir(ps) # functions available in PorterStemmer
# Out:
# ['MARTIN_EXTENSIONS',
#  'NLTK_EXTENSIONS',
#  'ORIGINAL_ALGORITHM',
#  '__abstractmethods__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_apply_rule_list',
#  '_contains_vowel',
#  '_ends_cvc',
#  '_ends_double_consonant',
#  '_has_positive_measure',
#  '_is_consonant',
#  '_measure',
#  '_replace_suffix',
#  '_step1a',
#  '_step1b',
#  '_step1c',
#  '_step2',
#  '_step3',
#  '_step4',
#  '_step5a',
#  '_step5b',
#  'mode',
#  'pool',
#  'stem',
#  'vowels']

# %%
print(ps.stem('coder'))
print(ps.stem('coding'))
print(ps.stem('got'))
# Out:
# coder
# code
# got

# %%
def stemming(text_no_stopword):
  text = [ps.stem(word) for word in text_no_stopword]
  return text

df['text_stemmed'] = df['text_no_stopword'].apply(lambda x: stemming(x))

# %%
df.head()
# Out:
#                                                 text  deceptive_LabEnc  \
# 0  We stayed for a one night getaway with family ...                 1
# 1  Triple A rate with upgrade to view room was le...                 1
# 2  This comes a little late as I'm finally catchi...                 1
# 3  The Omni Chicago really delivers on all fronts...                 1
# 4  I asked for a high floor away from the elevato...                 1
#
#                                         text_no_punc  \
# 0  We stayed for a one night getaway with family ...
# 1  Triple A rate with upgrade to view room was le...
# 2  This comes a little late as Im finally catchin...
# 3  The Omni Chicago really delivers on all fronts...
# 4  I asked for a high floor away from the elevato...
#
#                                       text_tokenized  \
# 0  [we, stayed, for, a, one, night, getaway, with...
# 1  [triple, a, rate, with, upgrade, to, view, roo...
# 2  [this, comes, a, little, late, as, im, finally...
# 3  [the, omni, chicago, really, delivers, on, all...
# 4  [i, asked, for, a, high, floor, away, from, th...
#
#                                     text_no_stopword  \
# 0  [stayed, one, night, getaway, family, thursday...
# 1  [triple, rate, upgrade, view, room, less, 200,...
# 2  [comes, little, late, im, finally, catching, r...
# 3  [omni, chicago, really, delivers, fronts, spac...
# 4  [asked, high, floor, away, elevator, got, room...
#
#                                         text_stemmed
# 0  [stay, one, night, getaway, famili, thursday, ...
# 1  [tripl, rate, upgrad, view, room, less, 200, a...
# 2  [come, littl, late, im, final, catch, review, ...
# 3  [omni, chicago, realli, deliv, front, spacious...
# 4  [ask, high, floor, away, elev, got, room, plea...

# %%
df.drop('text', axis=1, inplace=True)

# %%
df.drop('text_no_punc', axis=1, inplace=True)

# %%
df.drop('text_tokenized', axis=1, inplace=True)

# %%
df.drop('text_no_stopword', axis=1, inplace=True)

# %%
df.head()
# Out:
#    deceptive_LabEnc                                       text_stemmed
# 0                 1  [stay, one, night, getaway, famili, thursday, ...
# 1                 1  [tripl, rate, upgrad, view, room, less, 200, a...
# 2                 1  [come, littl, late, im, final, catch, review, ...
# 3                 1  [omni, chicago, realli, deliv, front, spacious...
# 4                 1  [ask, high, floor, away, elev, got, room, plea...

# %% [markdown]
# **Separate data into X and Y:**

# %%
X = df.text_stemmed
Y = df.deceptive_LabEnc

# %%
X = X.astype(str)

# %% [markdown]
# **Split the data into train, validation and test:**

# %%
from sklearn.model_selection import train_test_split
X_main, X_test, Y_main, Y_test = train_test_split(X, Y, test_size=0.2, random_state=1, stratify=Y)
X_train, X_val, Y_train, Y_val = train_test_split(X_main, Y_main, test_size=0.2, random_state=1, stratify=Y_main)

# %% [markdown]
# # **Second Phase: FEATURE ENGINEERING**

# %% [markdown]
# **Count Vectorization:**

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
cv = CountVectorizer()
X_train_cv = cv.fit_transform(X_train)
a = X_train_cv.toarray()
X_val_cv = cv.transform(X_val)
b = X_val_cv.toarray()

# %%
X_train_cv.shape
# Out:
# (1024, 6108)

# %%
b.shape
# Out:
# (256, 6108)

# %%
#cv.vocabulary_
#cv.get_feature_names()

# %%
#The converse mapping from feature name to column index is stored in the vocabulary_ attribute of the vectorizer:
cv.vocabulary_.get('good')
# Out:
# 2490

# %% [markdown]
# # **Third Phase: CLASSIFIER MODELS & PERFORMANCE EVALUATION**

# %% [markdown]
# **Data standardization:**

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(a)
X_val = scaler.transform(b)

# %% [markdown]
# **1. Logistic Regression Model:**

# %%
from sklearn.linear_model import LogisticRegression
log_reg = LogisticRegression()
log_reg.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %%
Y_val_predict = log_reg.predict(X_val)

# %% [markdown]
# **Evaluation of the model on validation data:**

# %% [markdown]
# **i. Accuracy score:**

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(Y_val, Y_val_predict))
# Out:
# 0.80078125

# %% [markdown]
# **ii. Classification report:**

# %%
from sklearn.metrics import classification_report
print(classification_report(Y_val, Y_val_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.86      0.81       128
#            1       0.84      0.74      0.79       128
#
#     accuracy                           0.80       256
#    macro avg       0.80      0.80      0.80       256
# weighted avg       0.80      0.80      0.80       256

# %% [markdown]
# **iii. Confusion matrix:**

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

cm = confusion_matrix(Y_val, Y_val_predict)
cm1 = pd.DataFrame(data=cm, index=['Deceptive','Truthful'],columns=['Deceptive','Truthful'])
cm1
# Out:
#            Deceptive  Truthful
# Deceptive        110        18
# Truthful          33        95

# %% [markdown]
# **Evaluation of the model on test data:**

# %%
X_test_cv = cv.transform(X_test)
c = X_test_cv.toarray()

# %%
X_test = scaler.transform(c)

# %%
Y_test_predict = log_reg.predict(X_test)

# %% [markdown]
# **i. Accuracy score:**

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(Y_test, Y_test_predict))
# Out:
# 0.815625

# %% [markdown]
# **ii. Classification report:**

# %%
from sklearn.metrics import classification_report
print(classification_report(Y_test, Y_test_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.87      0.82       160
#            1       0.85      0.76      0.81       160
#
#     accuracy                           0.82       320
#    macro avg       0.82      0.82      0.82       320
# weighted avg       0.82      0.82      0.82       320

# %% [markdown]
# **iii. Confusion matrix:**

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

cm = confusion_matrix(Y_test, Y_test_predict)
cm1 = pd.DataFrame(data=cm, index=['Deceptive','Truthful'],columns=['Deceptive','Truthful'])
cm1
# Out:
#            Deceptive  Truthful
# Deceptive        139        21
# Truthful          38       122

# %% [markdown]
# **2. Decision Tree Model:**

# %%
from sklearn.tree import DecisionTreeClassifier
dec_tree_model = DecisionTreeClassifier()
dec_tree_model.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier()

# %%
Y_val_predict = dec_tree_model.predict(X_val)

# %% [markdown]
# **Evaluation of the model on validation data:**

# %% [markdown]
# **i. Accuracy score:**

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(Y_val, Y_val_predict))
# Out:
# 0.58984375

# %% [markdown]
# **ii. Classification report:**

# %%
from sklearn.metrics import classification_report
print(classification_report(Y_val, Y_val_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.59      0.62      0.60       128
#            1       0.60      0.56      0.58       128
#
#     accuracy                           0.59       256
#    macro avg       0.59      0.59      0.59       256
# weighted avg       0.59      0.59      0.59       256

# %% [markdown]
# **iii. Confusion matrix:**

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

cm = confusion_matrix(Y_val, Y_val_predict)
cm1 = pd.DataFrame(data=cm, index=['Deceptive','Truthful'],columns=['Deceptive','Truthful'])
cm1
# Out:
#            Deceptive  Truthful
# Deceptive         79        49
# Truthful          56        72

# %% [markdown]
# **Evaluation of the model on test data:**

# %%
Y_test_predict = dec_tree_model.predict(X_test)

# %% [markdown]
# **i. Accuracy score:**

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(Y_test, Y_test_predict))
# Out:
# 0.671875

# %% [markdown]
# **ii. Classification report:**

# %%
from sklearn.metrics import classification_report
print(classification_report(Y_test, Y_test_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.68      0.66      0.67       160
#            1       0.67      0.68      0.67       160
#
#     accuracy                           0.67       320
#    macro avg       0.67      0.67      0.67       320
# weighted avg       0.67      0.67      0.67       320

# %% [markdown]
# **iii. Confusion matrix:**

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

cm = confusion_matrix(Y_test, Y_test_predict)
cm1 = pd.DataFrame(data=cm, index=['Deceptive','Truthful'],columns=['Deceptive','Truthful'])
cm1
# Out:
#            Deceptive  Truthful
# Deceptive        106        54
# Truthful          51       109

# %% [markdown]
# **3. Support Vector Machine Model:**

# %%
from sklearn import svm
svm_model = svm.SVC()
svm_model.fit(X_train, Y_train)
# Out:
# SVC()

# %%
Y_val_predict = svm_model.predict(X_val)

# %% [markdown]
# **Evaluation of the model on validation data:**

# %% [markdown]
# **i. Accuracy score:**

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(Y_val, Y_val_predict))
# Out:
# 0.703125

# %% [markdown]
# **ii. Classification report:**

# %%
from sklearn.metrics import classification_report
print(classification_report(Y_val, Y_val_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.64      0.91      0.75       128
#            1       0.84      0.50      0.63       128
#
#     accuracy                           0.70       256
#    macro avg       0.74      0.70      0.69       256
# weighted avg       0.74      0.70      0.69       256

# %% [markdown]
# **iii. Confusion matrix:**

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

cm = confusion_matrix(Y_val, Y_val_predict)
cm1 = pd.DataFrame(data=cm, index=['Deceptive','Truthful'],columns=['Deceptive','Truthful'])
cm1
# Out:
#            Deceptive  Truthful
# Deceptive        116        12
# Truthful          64        64

# %% [markdown]
# **Evaluation of the model on test data:**

# %%
Y_test_predict = svm_model.predict(X_test)

# %% [markdown]
# **i. Accuracy score:**

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(Y_test, Y_test_predict))
# Out:
# 0.6875

# %% [markdown]
# **ii. Classification report:**

# %%
from sklearn.metrics import classification_report
print(classification_report(Y_test, Y_test_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.64      0.86      0.73       160
#            1       0.78      0.52      0.62       160
#
#     accuracy                           0.69       320
#    macro avg       0.71      0.69      0.68       320
# weighted avg       0.71      0.69      0.68       320

# %% [markdown]
# **iii. Confusion matrix:**

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

cm = confusion_matrix(Y_test, Y_test_predict)
cm1 = pd.DataFrame(data=cm, index=['Deceptive','Truthful'],columns=['Deceptive','Truthful'])
cm1
# Out:
#            Deceptive  Truthful
# Deceptive        137        23
# Truthful          77        83
